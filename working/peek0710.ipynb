# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# PRFX='Mel0713C1'
# PRFX='Mel0713B1'
PRFX='Mel0718A1'
p_out = f'../output/{PRFX}'

class Param: pass

# !ls | grep {PRFX}

res = pickle.load(open(f'{p_out}/results_{PRFX}.p', 'rb'))

fld2stats=res['fld2stats']
# Out:
# Mel0718A1__B4SZ384_noTTA4val_noVal20.ipynb

# %%
for fld,stats in fld2stats.items():
    print(f"best_scr: {stats['best_scr']:.3f}; best_epc: {stats['best_epc']}; best_scr20: {stats['best_scr20']:.3f}; best_epc20: {stats['best_epc20']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-340-dff27b624233> in <module>
#       1 for fld,stats in fld2stats.items():
# ----> 2     print(f"best_scr: {stats['best_scr']:.3f}; best_epc: {stats['best_epc']}; best_scr20: {stats['best_scr20']:.3f}; best_epc20: {stats['best_epc20']}")
#
# KeyError: 'best_scr20'

# %%
for fld,stats in fld2stats.items():
    print(f"best_scr: {stats['best_scr']:.3f}; best_epc: {stats['best_epc']}; best_scr20: {stats['best_scr20']:.3f}; best_epc20: {stats['best_epc20']}")
# Out:
# best_scr: 0.931; best_epc: 7; best_scr20: 0.940; best_epc20: 8
# best_scr: 0.932; best_epc: 7; best_scr20: 0.919; best_epc20: 6
# best_scr: 0.940; best_epc: 4; best_scr20: 0.912; best_epc20: 5

# %%
for mtrc in ['lss', 'scr']:
    for k in ['tr','vl','vl20']:
        plt.title(f'{mtrc} {k}')
        for fld in range(5):
            try:
                plt.plot(fld2stats[fld][mtrc][k], 'o--')
            except KeyError as e:
                print(e)
        plt.show()
# Out:
# 3
# 4
# 3
# 4
# 3
# 4
# 3
# 4
# 3
# 4
# 3
# 4
