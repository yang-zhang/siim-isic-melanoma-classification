# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
# PRFX='Mel0705E3'
PRFX='Mel0711B2'
p_out = f'../output/{PRFX}'

class Param: pass

# %%
ls | grep {PRFX}
# Out:
# Mel0711B2__B1SZ348__lowLR_changePlatParams.ipynb

# %%
res = pickle.load(open(f'{p_out}/results_{PRFX}.p', 'rb'))

res['param'].__dict__
stats=res['stats']

# %%
for mtrc in ['lss', 'scr']:
    recs=stats[mtrc]
    for tv,vs in recs.items():
        plt.title(f'{mtrc}')
        plt.plot(vs, 'o--')
    plt.show()

# %%
print(f'best_scr {stats["best_scr"]:.4f}; best_epc {stats["best_epc"]}; best_scr20 {stats["best_scr20"]:.4f}; best_epc20 {stats["best_epc20"]}')
# Out:
# best_scr 0.9389; best_epc 4; best_scr20 0.9188; best_epc20 21

# %%
pd.DataFrame(stats['scr']).sort_values('vl20', ascending=False).head(10)
# Out:
#           tr        vl      vl20
# 21  0.979764  0.938148  0.918796
# 15  0.980886  0.937949  0.918228
# 16  0.978961  0.938372  0.918214
# 9   0.976719  0.937391  0.918195
# 8   0.976353  0.936826  0.918160
# 13  0.979951  0.938343  0.918087
# 17  0.981018  0.938285  0.917968
# 10  0.977497  0.938281  0.917904
# 11  0.978725  0.938562  0.917700
# 18  0.980280  0.938182  0.917693
