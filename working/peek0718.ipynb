# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# PRFX='Mel0713C1'
# PRFX='Mel0713B1'
PRFX='Mel0718A2'
p_out = f'../output/{PRFX}'

class Param: pass

# !ls | grep {PRFX}

res = pickle.load(open(f'{p_out}/results_{PRFX}.p', 'rb'))

fld2stats=res['fld2stats']
# Out:
# Mel0718A2__B4SZ384.ipynb

# %%
for fld,stats in fld2stats.items():
    print(f"best_scr: {stats['best_scr']:.3f}; best_epc: {stats['best_epc']};")
# Out:
# best_scr: 0.917; best_epc: 3;
# best_scr: 0.921; best_epc: 4;
# best_scr: 0.931; best_epc: 5;
# best_scr: 0.917; best_epc: 6;

# %%
for mtrc in ['lss', 'scr']:
    for k in ['tr','vl',]:
        plt.title(f'{mtrc} {k}')
        for fld in range(5):
            try:
                plt.plot(fld2stats[fld][mtrc][k], 'o--')
            except KeyError as e:
                print(e)
        plt.show()
# Out:
# 4
# 4
# 4
# 4
