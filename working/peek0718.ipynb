# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

PRFX='Mel0719D1'
p_out = f'../output/{PRFX}'

class Param: pass

# !ls | grep {PRFX}

res = pickle.load(open(f'{p_out}/results_{PRFX}.p', 'rb'))

fld2stats=res['fld2stats']
# Out:
# Mel0719D1__B2SZ384__onlyShapeAugs.ipynb

# %%
for fld,stats in fld2stats.items():
    print(f"best_scr: {stats['best_scr']:.3f}; best_epc: {stats['best_epc']};")
# Out:
# best_scr: 0.924; best_epc: 7;
# best_scr: 0.921; best_epc: 3;
# best_scr: 0.935; best_epc: 3;
# best_scr: 0.924; best_epc: 8;
# best_scr: 0.933; best_epc: 4;

# %%
for mtrc in ['lss', 'scr']:
    for k in ['tr','vl',]:
        plt.title(f'{mtrc} {k}')
        for fld in range(5):
            try:
                plt.plot(fld2stats[fld][mtrc][k], 'o--')
            except KeyError as e:
                print(e)
        plt.show()
