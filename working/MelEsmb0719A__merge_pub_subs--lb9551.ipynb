# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fnms=['agentauers--incredible-tpus-finetune-effnetb0-b6-at-once--v8--submission_models_blended.csv',
'cdeotte--triple-stratified-kfold-with-tfrecords--v5--submission.csv',
'mahmudds--siim-isic-melanoma-classification--v8--submission.csv',
'orionpax00--weighted-average-image-and-tabular--v1--submission.csv',
'ragnar123--ligthgbm-stack-groupkfold--v7--lgbm_baseline_sub.csv',
# 'redwankarimsony--siim-isic-melanoma-classification-ensemble--v30--submission.csv',
'shivam17818--test-all-efficientnet-model-b0-b7--v16--submission.csv',
'solomonk--classification-np-log2-ensemble-0-9504-lb--v6--submission.csv',
'solomonk--minmax-ensemble-0-9526-lb--v19--submission.csv',
'truonghoang--stacking-ensemble-on-my-submissions--v15--submission_mean.csv',]

# %%
lst=[pd.read_csv(f'../input/pubsubs/{o}') for o in fnms]

# %%
for df in lst:
    print(df.shape, df.target.mean())
    plt.hist(df.target, bins=50)
    plt.show()
# Out:
# (10982, 2) 0.05265084443188866
# (10982, 2) 0.045882459764870535
# (10982, 2) 0.04673463112234815
# (10982, 2) 0.04889412755542924
# (10982, 2) 0.023474031747556662
# (10982, 2) 0.04628819537078867
# (10982, 2) 0.04538099717719911
# (10982, 2) 0.025650043596535
# (10982, 2) 0.05063115352394846

# %%
prds = np.mean([df.target.values for df in lst], 0)
prds.shape
# Out:
# (10982,)

# %%
dfsub = pd.read_csv('../input/siim-isic-melanoma-classification/sample_submission.csv')
dfsub.target=prds
dfsub.target.mean()
# Out:
# 0.042842942698951586

# %%
plt.hist(dfsub.target, bins=50);

# %%
dfsub.to_csv('../output/submission_MelEsmb0719A.csv', index=False)
