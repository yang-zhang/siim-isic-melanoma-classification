# %%
import pickle
import matplotlib.pyplot as plt

# %%
# PRFX='Mel0705B1'
PRFX='Mel0705C1'
p_out = f'../output/{PRFX}'

class Param: pass

# %%
ls | grep {PRFX}
# Out:
# Mel0705C1__B0-dbgrun.ipynb
# Mel0705C1__B0__inferDuringTrain.ipynb

# %%
res = pickle.load(open(f'{p_out}/results_{PRFX}.p', 'rb'))

res['param'].__dict__
stats=res['stats']

# %%
for mtrc in ['lss', 'scr']:
    recs=stats[mtrc]
    for tv,vs in recs.items():
        plt.title(f'{mtrc}')
        plt.plot(vs, 'o--')
    plt.show()

# %%
print(f'best_scr {stats["best_scr"]:.4f}; best_epc {stats["best_epc"]}; best_scr20 {stats["best_scr20"]:.4f}; best_epc20 {stats["best_epc20"]}')
# Out:
# best_scr 0.9380; best_epc 11; best_scr20 0.9133; best_epc20 11
