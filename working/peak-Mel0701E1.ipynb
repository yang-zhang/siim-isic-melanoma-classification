# %%
import pickle
import matplotlib.pyplot as plt

# %%
PRFX='Mel0701E1'
p_out = f'../output/{PRFX}'

class Param: pass

# %%
ls | grep {PRFX}
# Out:
# Mel0701E1__B0_GeM--cv888.ipynb
# Mel0701E1__B0_GeM-dbgrun.ipynb
# Mel0701E1__B1__WD=0.ipynb

# %%
res = pickle.load(open(f'{p_out}/results_{PRFX}.p', 'rb'))

res['param'].__dict__
stats=res['stats']

# %%
for mtrc in ['lss', 'scr']:
    recs=stats[mtrc]
    for tv,vs in recs.items():
        plt.title(f'{mtrc}')
        plt.plot(vs, 'o--')
    plt.show()

# %%
print(f'best_scr {stats["best_scr"]:.4f}; best_epc {stats["best_epc"]}')
# Out:
# best_scr 0.9258; best_epc 31
